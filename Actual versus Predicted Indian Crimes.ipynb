# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
crime = pd.read_csv("crime.csv")

# %%
crime
# Out:
#             STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     Andhra Pradesh     ADILABAD  2013      96                 72
# 1     Andhra Pradesh    ANANTAPUR  2013     156                149
# 2     Andhra Pradesh     CHITTOOR  2013      72                 61
# 3     Andhra Pradesh     CUDDAPAH  2013      93                107
# 4     Andhra Pradesh    CYBERABAD  2013     162                123
# ...              ...          ...   ...     ...                ...
# 9835        DELHI UT         WEST  2001      70                 51
# 9836     LAKSHADWEEP  LAKSHADWEEP  2001       1                  0
# 9837     LAKSHADWEEP        TOTAL  2001       1                  0
# 9838      PUDUCHERRY  PONDICHERRY  2001      25                 32
# 9839      PUDUCHERRY        TOTAL  2001      25                 32
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                            13    61               0
# ...

# %%
crime.head()
# Out:
#          STATE/UT   DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  Andhra Pradesh   ADILABAD  2013      96                 72
# 1  Andhra Pradesh  ANANTAPUR  2013     156                149
# 2  Andhra Pradesh   CHITTOOR  2013      72                 61
# 3  Andhra Pradesh   CUDDAPAH  2013      93                107
# 4  Andhra Pradesh  CYBERABAD  2013     162                123
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         13    61               0
# 1                                          3    28               0
# 2                                          2    31               0
# 3                                          7    19               0
# 4                                         16   138               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          61                      65  ...     30                2394
# ...

# %%
crime.tail()
# Out:
#          STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 9835     DELHI UT         WEST  2001      70                 51
# 9836  LAKSHADWEEP  LAKSHADWEEP  2001       1                  0
# 9837  LAKSHADWEEP        TOTAL  2001       1                  0
# 9838   PUDUCHERRY  PONDICHERRY  2001      25                 32
# 9839   PUDUCHERRY        TOTAL  2001      25                 32
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 9835                                         12    45               0
# 9836                                          0     0               0
# 9837                                          0     0               0
# 9838                                          1     9               0
# 9839                                          1     9               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 9835          45                     151  ...      3                 252
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
# ...

# %%
crime.isna().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# ...

# %%
crime.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
# convert the STATE/UT and DISTRICT columns to uppercase
crime['STATE/UT'] = crime['STATE/UT'].str.upper()
crime['DISTRICT'] = crime['DISTRICT'].str.upper()

# %%
crime['STATE/UT'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A&N ISLANDS', 'CHANDIGARH', 'D&N HAVELI',
#        'DAMAN & DIU', 'DELHI UT', 'LAKSHADWEEP', 'PUDUCHERRY',
#        'A & N ISLANDS', 'D & N HAVELI'], dtype=object)

# %%
def state(name):
    state = crime.groupby(['STATE/UT','DISTRICT','YEAR']).sum()['TOTAL IPC CRIMES']
    return state[name]

# %%
state('MAHARASHTRA')
# Out:
# DISTRICT    YEAR
# AHMEDNAGAR  2001      4391
#             2002      4506
#             2003      4251
#             2004      4738
#             2005      5241
#                      ...
# YAVATMAL    2010      4777
#             2011      5008
#             2012      6365
#             2013     12567
# ZZ TOTAL    2013    234385
# Name: TOTAL IPC CRIMES, Length: 598, dtype: int64

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
# ...

# %% [markdown]
# # Statistical Data Analysis

# %%
import math
import statistics
import scipy.stats as stats

# %% [markdown]
# # 1. Descriptive Statistics

# %%
crime.describe()
# Out:
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  9840.000000  9840.000000        9840.000000
# mean   2007.161890    88.565854          78.738618
# std       3.755581   325.417692         306.650391
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          28.000000
# 75%    2010.000000    66.000000          57.000000
# max    2013.000000  7601.000000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9840.000000  9840.000000     9840.000000
# mean                                    9.754878    55.456098        0.005488
# std                                    58.733349   201.690457        0.111218
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %% [markdown]
# # 1.1 Measure of Central Tendancy

# %% [markdown]
# # Mean

# %%
numeric_crime = crime.select_dtypes(include='number')  # Select numeric columns only
print(numeric_crime.mean())
mean_values = crime.mean(numeric_only=True)  # Calculate the mean for numeric data only
print(mean_values)
# Out:
# YEAR                                                   2007.161890
# MURDER                                                   88.565854
# ATTEMPT TO MURDER                                        78.738618
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                 9.754878
# RAPE                                                     55.456098
# CUSTODIAL RAPE                                            0.005488
# OTHER RAPE                                               55.450610
# KIDNAPPING & ABDUCTION                                   85.836992
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS              64.184553
# KIDNAPPING AND ABDUCTION OF OTHERS                       21.652439
# DACOITY                                                  12.997561
# PREPARATION AND ASSEMBLY FOR DACOITY                      7.134146
# ROBBERY                                                  56.950000
# BURGLARY                                                248.321138
# ...

# %%
crime['TOTAL IPC CRIMES'].mean()
# Out:
# 5404.141463414634

# %% [markdown]
# # Mode

# %%
crime.mode()
# Out:
#         STATE/UT DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  UTTAR PRADESH    TOTAL  2013       0                  0
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                          0     0               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0           0                       0  ...      0                   0
#
#    DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0             0                                                  0
#
#    INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                           0                                    0
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                            0
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0                 0               248
#
# [1 rows x 33 columns]

# %%
crime['TOTAL IPC CRIMES'].mode()
# Out:
# 0    248
# Name: TOTAL IPC CRIMES, dtype: int64

# %% [markdown]
# #  Median

# %%
statistics.median(crime['THEFT'])
# Out:
# 218.5

# %%
numeric_crime = crime.select_dtypes(include='number')  # Select numeric columns only
print(numeric_crime.median())
median_values = crime.median(numeric_only=True)  # Calculate the median for numeric data only
print(median_values)
# Out:
# YEAR                                                   2007.0
# MURDER                                                   37.0
# ATTEMPT TO MURDER                                        28.0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                 2.0
# RAPE                                                     21.0
# CUSTODIAL RAPE                                            0.0
# OTHER RAPE                                               21.0
# KIDNAPPING & ABDUCTION                                   26.0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS              19.0
# KIDNAPPING AND ABDUCTION OF OTHERS                        5.0
# DACOITY                                                   3.0
# PREPARATION AND ASSEMBLY FOR DACOITY                      0.0
# ROBBERY                                                  17.0
# BURGLARY                                                 83.0
# THEFT                                                   218.5
# ...

# %% [markdown]
# # 1.2 Measure of Variability/Dispersion

# %% [markdown]
# # Variance

# %% [markdown]
# Variance is a measure of how spread out a set of data is. It is calculated by taking the average of the squared differences between each data point and the mean of the data set.

# %%
statistics.variance(crime['THEFT'])
# Out:
# 8952038.115188519

# %%
numeric_crime = crime.select_dtypes(include='number')  # Select numeric columns
variance = np.var(numeric_crime)  # Calculate variance
print(variance)
# Out:
# YEAR                                                   1.410296e+01
# MURDER                                                 1.058859e+05
# ATTEMPT TO MURDER                                      9.402491e+04
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              3.449256e+03
# RAPE                                                   4.067491e+04
# CUSTODIAL RAPE                                         1.236826e-02
# OTHER RAPE                                             4.066916e+04
# KIDNAPPING & ABDUCTION                                 1.253283e+05
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            7.757467e+04
# KIDNAPPING AND ABDUCTION OF OTHERS                     8.791801e+03
# DACOITY                                                3.161497e+03
# PREPARATION AND ASSEMBLY FOR DACOITY                   1.844410e+03
# ROBBERY                                                5.906979e+04
# BURGLARY                                               8.971025e+05
# ...

# %% [markdown]
# # Standard Deviation

# %% [markdown]
# standard deviation is a measure of the amount of variation or dispersion of a set of data values around their mean or average value. It is the square root of the variance of the data set, and is expressed in the same units as the original data.

# %%
import numpy as np

# Select only numeric columns
numeric_crime = crime.select_dtypes(include='number')

# Calculate standard deviation
std_dev = np.std(numeric_crime)
print(std_dev)
# Out:
# YEAR                                                       3.755391
# MURDER                                                   325.401156
# ATTEMPT TO MURDER                                        306.634808
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                 58.730365
# RAPE                                                     201.680208
# CUSTODIAL RAPE                                             0.111213
# OTHER RAPE                                               201.665954
# KIDNAPPING & ABDUCTION                                   354.017369
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS              278.522296
# KIDNAPPING AND ABDUCTION OF OTHERS                        93.764606
# DACOITY                                                   56.227187
# PREPARATION AND ASSEMBLY FOR DACOITY                      42.946600
# ROBBERY                                                  243.042774
# BURGLARY                                                 947.154976
# ...

# %%
statistics.stdev(crime['THEFT'])
# Out:
# 2991.995674326505

# %% [markdown]
# # Range

# %%
numeric_data = crime.select_dtypes(exclude='object')

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 31 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   YEAR                                                 9840 non-null   int64
#  1   MURDER                                               9840 non-null   int64
#  2   ATTEMPT TO MURDER                                    9840 non-null   int64
#  3   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  4   RAPE                                                 9840 non-null   int64
#  5   CUSTODIAL RAPE                                       9840 non-null   int64
#  6   OTHER RAPE                                           9840 non-null   int64
#  7   KIDNAPPING & ABDUCTION                               9840 non-null   int64
# ...

# %%
for col in numeric_data.columns:
    range = crime[col].max() - crime[col].min()
    print('range of %s : %d'%(col,range))
# Out:
# range of YEAR : 12
# range of MURDER : 7601
# range of ATTEMPT TO MURDER : 7964
# range of CULPABLE HOMICIDE NOT AMOUNTING TO MURDER : 1616
# range of RAPE : 4335
# range of CUSTODIAL RAPE : 5
# range of OTHER RAPE : 4335
# range of KIDNAPPING & ABDUCTION : 11183
# range of KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS : 9737
# range of KIDNAPPING AND ABDUCTION OF OTHERS : 2685
# range of DACOITY : 1319
# range of PREPARATION AND ASSEMBLY FOR DACOITY : 1263
# range of ROBBERY : 9746
# range of BURGLARY : 18328
# range of THEFT : 53449
# range of AUTO THEFT : 24948
# range of OTHER THEFT : 35960
# range of RIOTS : 11931
# range of CRIMINAL BREACH OF TRUST : 4296
# range of CHEATING : 22796
# range of COUNTERFIETING : 599
# range of ARSON : 2830
# range of HURT/GREVIOUS HURT : 60488
# range of DOWRY DEATHS : 2335
# range of ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY : 8252
# range of INSULT TO MODESTY OF WOMEN : 4970
# range of CRUELTY BY HUSBAND OR HIS RELATIVES : 19865
# ...

# %% [markdown]
# # Inter-Quartile Range

# %%
for col in numeric_data.columns:
    Q1 = crime[col].quantile(.25)
    Q3 = crime[col].quantile(.75)
    IQR = Q3 - Q1
    print('IQR of %s : %d' %(col,IQR))
# Out:
# IQR of YEAR : 6
# IQR of MURDER : 48
# IQR of ATTEMPT TO MURDER : 47
# IQR of CULPABLE HOMICIDE NOT AMOUNTING TO MURDER : 6
# IQR of RAPE : 35
# IQR of CUSTODIAL RAPE : 0
# IQR of OTHER RAPE : 35
# IQR of KIDNAPPING & ABDUCTION : 50
# IQR of KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS : 40
# IQR of KIDNAPPING AND ABDUCTION OF OTHERS : 12
# IQR of DACOITY : 8
# IQR of PREPARATION AND ASSEMBLY FOR DACOITY : 2
# IQR of ROBBERY : 32
# IQR of BURGLARY : 148
# IQR of THEFT : 383
# IQR of AUTO THEFT : 135
# IQR of OTHER THEFT : 248
# IQR of RIOTS : 114
# IQR of CRIMINAL BREACH OF TRUST : 24
# IQR of CHEATING : 96
# IQR of COUNTERFIETING : 4
# IQR of ARSON : 17
# IQR of HURT/GREVIOUS HURT : 489
# IQR of DOWRY DEATHS : 15
# IQR of ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY : 70
# IQR of INSULT TO MODESTY OF WOMEN : 13
# IQR of CRUELTY BY HUSBAND OR HIS RELATIVES : 128
# IQR of IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES : 0
# IQR of CAUSING DEATH BY NEGLIGENCE : 175
# ...

# %% [markdown]
# # Percentiles

# %% [markdown]
# A percentile is a measure that indicates the percentage of observations in a dataset that fall below a particular value.
# For example, the 75th percentile of a dataset is the value below which 75% of the observations in the dataset fall. This means that 25% of the observations in the dataset are greater than the 75th percentile.

# %%
percentiles = crime.describe(percentiles=[.01, .25, .5, .75, .99]).transpose()[["1%", "25%", "50%", "75%", "99%"]]
percentiles
# Out:
#                                                         1%      25%     50%  \
# YEAR                                                2001.0  2004.00  2007.0
# MURDER                                                 0.0    18.00    37.0
# ATTEMPT TO MURDER                                      0.0    10.00    28.0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0.0     0.00     2.0
# RAPE                                                   0.0     8.00    21.0
# CUSTODIAL RAPE                                         0.0     0.00     0.0
# OTHER RAPE                                             0.0     8.00    21.0
# KIDNAPPING & ABDUCTION                                 0.0    10.00    26.0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0.0     6.00    19.0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0.0     2.00     5.0
# DACOITY                                                0.0     1.00     3.0
# ...

# %%
#We can also find different percentiles of particular column
crime['THEFT'].quantile([0.1,0.2,0.4,0.5])
# Out:
# 0.1     30.0
# 0.2     69.0
# 0.4    159.0
# 0.5    218.5
# Name: THEFT, dtype: float64

# %% [markdown]
# # Mean Absolute Deviation(MAD)

# %%
mad = crime.select_dtypes(include='number').apply(lambda x: (x - x.mean()).abs().mean())
print(mad)
# Out:
# YEAR                                                      3.256694
# MURDER                                                   92.490644
# ATTEMPT TO MURDER                                        88.619918
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER                12.825256
# RAPE                                                     60.363597
# CUSTODIAL RAPE                                            0.010932
# OTHER RAPE                                               60.357509
# KIDNAPPING & ABDUCTION                                  100.038268
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS              75.935080
# KIDNAPPING AND ABDUCTION OF OTHERS                       27.275226
# DACOITY                                                  15.986659
# PREPARATION AND ASSEMBLY FOR DACOITY                     10.888722
# ROBBERY                                                  67.982825
# BURGLARY                                                284.300979
# ...

# %% [markdown]
# # 1.3 Measure of Shape

# %% [markdown]
# # Skewness

# %% [markdown]
# Skewness is a measure of the asymmetry of a probability distribution, which indicates whether the data is symmetric or skewed to one side. In other words, it measures the degree of deviation of a distribution from a normal or bell-shaped curve.

# %%
crime_numeric = crime.select_dtypes(include=['number'])  # Exclude non-numeric columns
skewness = crime_numeric.skew()
print(skewness)
# Out:
# YEAR                                                   -0.052110
# MURDER                                                 10.586544
# ATTEMPT TO MURDER                                      11.216619
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              20.356354
# RAPE                                                    9.939488
# CUSTODIAL RAPE                                         32.660692
# OTHER RAPE                                              9.940215
# KIDNAPPING & ABDUCTION                                 13.355613
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            15.426410
# KIDNAPPING AND ABDUCTION OF OTHERS                     13.111622
# DACOITY                                                12.606410
# PREPARATION AND ASSEMBLY FOR DACOITY                   17.108085
# ROBBERY                                                15.172991
# BURGLARY                                               10.412429
# ...

# %%
crime['THEFT'].plot(kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(crime['YEAR'],hist=True,kde=True)
# Out:
# <Axes: xlabel='YEAR', ylabel='Density'>

# %%
sns.displot(crime, x="THEFT", hue="YEAR", kind="kde", multiple="stack")

# %% [markdown]
# # Kurtosis

# %% [markdown]
# Kurtosis is a measure of the "peakedness" or "flatness" of a probability distribution, which describes how much of the distribution is concentrated around the central point, and how much is spread out towards the tails.
#
# A distribution with high kurtosis has a very sharp peak and heavy tails, indicating that it has more outliers and is more prone to extreme values. A distribution with low kurtosis is more flat-topped and has lighter tails, indicating that it has fewer outliers and is more stable.

# %%
# Select only numeric columns
crime_numeric = crime.select_dtypes(include='number')

# Calculate kurtosis on numeric columns only
kurtosis = crime_numeric.kurtosis()

print(kurtosis)
# Out:
# YEAR                                                     -1.220315
# MURDER                                                  144.991758
# ATTEMPT TO MURDER                                       165.067686
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               476.482702
# RAPE                                                    123.144254
# CUSTODIAL RAPE                                         1323.871144
# OTHER RAPE                                              123.164405
# KIDNAPPING & ABDUCTION                                  253.981863
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             348.619391
# KIDNAPPING AND ABDUCTION OF OTHERS                      232.755005
# DACOITY                                                 204.169477
# PREPARATION AND ASSEMBLY FOR DACOITY                    382.120594
# ROBBERY                                                 388.368214
# BURGLARY                                                135.563460
# ...

# %%
fig, ax = plt.subplots()
ax.hist(crime["MURDER"], bins=20)
ax.set_title("Histogram of MURDER")
ax.set_xlabel("Number of Murders")
ax.set_ylabel("Frequency")
plt.show()

# %%
plt.boxplot(crime["MURDER"])
plt.title("Kurtosis plot of MURDER")
plt.xlabel("MURDER")
plt.show()

# %% [markdown]
# By looking at the histogram and boxplot, we can get an idea of the kurtosis of the "MURDER" variable. A high peak in the histogram and a small box in the boxplot indicate a high kurtosis, while a more spread-out histogram and a larger box indicate a low kurtosis.

# %% [markdown]
# # Data visualization

# %%
# Convert TOTAL IPC CRIMES to numeric, coercing errors to NaN
crime['TOTAL IPC CRIMES'] = pd.to_numeric(crime['TOTAL IPC CRIMES'], errors='coerce')

# Group by 'YEAR' and calculate the mean
state = crime.groupby('YEAR').mean(numeric_only=True)
plt.figure(figsize=(15, 8))

# Plot 'TOTAL IPC CRIMES' for each year
plt.pie(state['TOTAL IPC CRIMES'], 
        labels=state.index, 
        startangle=90, shadow=True,
        textprops={'fontsize': 10, 'c': 'g'},
        autopct='%0.2f%%')

plt.title('CRIME in INDIA')
plt.show()

# %%
crime_totals = crime[['MURDER', 'RAPE', 'KIDNAPPING & ABDUCTION', 'ROBBERY', 'BURGLARY', 'THEFT']].sum()

# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(crime_totals.values, labels=crime_totals.index, autopct='%1.1f%%')
plt.title('Proportion of Crimes by Type')
plt.show()

# %%
# Group the data by state/union territory and sum the total number of IPC crimes
state_totals = crime.groupby('STATE/UT')['TOTAL IPC CRIMES'].sum()

# Create a bar chart
plt.figure(figsize=(15, 10))
plt.bar(state_totals.index, state_totals.values)
plt.xticks(rotation=90)
plt.xlabel('State/Union Territory')
plt.ylabel('Total IPC Crimes')
plt.title('Total IPC Crimes by State/Union Territory')
plt.show()

# %%
# Create a scatter plot of theft and burglary crimes
plt.figure(figsize=(12, 6))
plt.scatter(crime['THEFT'], crime['BURGLARY'])
plt.xlabel('Total Theft Crimes')
plt.ylabel('Total Burglary Crimes')
plt.title('Theft vs. Burglary Crimes')
plt.show()

# %% [markdown]
# # Correlation

# %% [markdown]
# In statistics, correlation is a measure of the strength and direction of the relationship between two variables. It indicates how closely the values of two variables are related to each other.
#
# The correlation matrix shows the correlation coefficients between each pair of variables. The correlation coefficient ranges between -1 and +1. A value of +1 indicates a perfect positive correlation, a value of 0 indicates no correlation, and a value of -1 indicates a perfect negative correlation.

# %%
# Select numeric columns only
numeric_crime = crime.select_dtypes(include=['number'])

# Calculate correlation matrix
correlation_matrix = numeric_crime.corr()

print(correlation_matrix)
# Out:
#                                                         YEAR    MURDER  \
# YEAR                                                1.000000 -0.014588
# MURDER                                             -0.014588  1.000000
# ATTEMPT TO MURDER                                   0.002504  0.957058
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER          -0.007766  0.783331
# RAPE                                                0.042352  0.804640
# CUSTODIAL RAPE                                     -0.004074  0.147950
# OTHER RAPE                                          0.042357  0.804615
# KIDNAPPING & ABDUCTION                              0.074994  0.812158
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         0.087115  0.769808
# KIDNAPPING AND ABDUCTION OF OTHERS                  0.024376  0.779709
# DACOITY                                            -0.035842  0.790893
# PREPARATION AND ASSEMBLY FOR DACOITY                0.016628  0.422544
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numeric columns only
numeric_crime = crime.select_dtypes(include=['number'])

# Calculate correlation matrix
correlation_matrix = numeric_crime.corr()

# Plot the heatmap
plt.figure(figsize=(25, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='icefire')
plt.title('Heatmap of Crime Data Correlation')
plt.show()

# %% [markdown]
# Looking at the correlation matrix, we can see that some variables are highly positively correlated with each other, such as "RAPE" and "OTHER RAPE" with a correlation coefficient of 1.00. Similarly, "KIDNAPPING & ABDUCTION" and "KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS" have a high positive correlation coefficient of 0.98.

# %% [markdown]
# # 2.Inferential Statistics

# %% [markdown]
# Hypothesis testing is a statistical method used to determine whether an observed effect or relationship in a sample of data is likely to represent a real effect or relationship in the population from which the sample was drawn.
#
# This involves stating a null hypothesis, which is the assumption that there is no relationship or effect in the population, and an alternative hypothesis, which is the opposite of the null hypothesis and represents the possibility of a real relationship or effect.

# %% [markdown]
# # Z-Test

# %%
from statsmodels.stats.weightstats import ztest

crime_data_2012 = crime[crime['YEAR'] == 2012]['TOTAL IPC CRIMES']
crime_data_2023 = crime[crime['YEAR'] == 2013]['TOTAL IPC CRIMES']

z_stat, p_value = ztest(crime_data_2012, crime_data_2023)
print('Z-test results')
print('Z-test statistic:',z_stat)
print('p-value:',p_value)
print()
if p_value < 0.05:
    print("Reject null hypothesis- There is a significant difference in the total IPC crimes between 2012 and 2013.")
else:
    print("Accept null hypothesis- There is no significant difference in the total IPC crimes between 2012 and 2013.")
# Out:
# Z-test results
# Z-test statistic: -0.5025809568806863
# p-value: 0.6152589207214316
#
# Accept null hypothesis- There is no significant difference in the total IPC crimes between 2012 and 2013.

# %% [markdown]
# The p-value is greater than 0.05, the null hypothesis is accepted, which means there is no significant difference in the mean total IPC crimes between 2012 and 2013.

# %% [markdown]
# # Anova Test

# %% [markdown]
# This test is used to determine whether the means of three or more independent groups are significantly different from each other. It is often used in studies that compare the means of multiple groups.

# %%
from scipy.stats import f_oneway

states = crime['STATE/UT'].unique()
murder_rates = {}
for state in states:
    murder_rates[state] = crime[crime['STATE/UT'] == state]['MURDER']

# Perform the ANOVA test
f_stat, p_value = f_oneway(*murder_rates.values())

# Output results
print('One-way ANOVA results')
print('F-statistic:', f_stat)
print('p-value:', p_value)  # Corrected variable name
print()

# Interpret the result
if p_value < 0.05:
    print("Reject null hypothesis- There is a significant difference in the mean number of murders across different states in India.")
else:
    print("Accept null hypothesis- There is no significant difference in the mean number of murders across different states in India.")
# Out:
# One-way ANOVA results
# F-statistic: 5.26264232613672
# p-value: 1.8145610596457112e-22
#
# Reject null hypothesis- There is a significant difference in the mean number of murders across different states in India.

# %% [markdown]
# If the ANOVA test indicates that there is a significant difference in the mean number of murders across different states in India, we can use a post-hoc Tukey test to determine which states have significantly different murder rates.
# If the ANOVA test does not find a significant difference, there is no need to perform a post-hoc test.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# perform the post-hoc Tukey test
tukey_results = pairwise_tukeyhsd(crime['MURDER'], crime['STATE/UT'])

print(tukey_results.summary())
# Out:
#               Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#       group1            group2       meandiff p-adj    lower      upper   reject
# --------------------------------------------------------------------------------
#     A & N ISLANDS       A&N ISLANDS   -5.8889    1.0  -661.3927  649.6149  False
#     A & N ISLANDS    ANDHRA PRADESH  160.6161 0.6006    -55.711  376.9431  False
#     A & N ISLANDS ARUNACHAL PRADESH   -0.3842    1.0  -224.4308  223.6624  False
#     A & N ISLANDS             ASSAM   75.8889    1.0  -140.6169  292.3947  False
#     A & N ISLANDS             BIHAR  143.8838 0.8064   -69.6876  357.4552  False
#     A & N ISLANDS        CHANDIGARH   11.4957    1.0  -308.6033  331.5948  False
#     A & N ISLANDS      CHHATTISGARH   79.2806    1.0   -140.292  298.8532  False
#     A & N ISLANDS      D & N HAVELI    0.1111    1.0  -327.6408   327.863  False
#     A & N ISLANDS        D&N HAVELI   -5.8889    1.0  -909.4386  897.6608  False
# ...

# %% [markdown]
# # T-Test

# %% [markdown]
# This test is used to determine whether the means of two independent samples are significantly different from each other. It is often used in studies that compare the means of two groups, such as a treatment group and a control group.

# %%
from scipy.stats import ttest_ind

state = 'ASSAM'
state_thefts = crime[crime['STATE/UT']==state]['THEFT']
other_thefts = crime[crime['STATE/UT']!=state]['THEFT']

t_stat, p_val = ttest_ind(state_thefts, other_thefts)

print("State:", state)
print("t-statistic:", t_stat)
print("p-value:", p_val)
print()
if p_val < 0.05:
    print('Reject null hypothesis - Significant difference found between thefts in', state, 'and all other states combined')
else:
    print('Accept null hypothesis - No significant difference found between thefts in', state, 'and all other states combined')
# Out:
# State: ASSAM
# t-statistic: -2.053521376564783
# p-value: 0.04004841519046039
#
# Reject null hypothesis - Significant difference found between thefts in ASSAM and all other states combined

# %% [markdown]
# The p-value is greater than or equal to 0.05, the null hypothesis is accepted and it is conclude that there is a significant difference between the mean number of thefts in Maharashtra and the mean number of thefts in all other states combined.

# %% [markdown]
# # chi-square test

# %% [markdown]
# This test is used to determine whether there is a significant association between two categorical variables. It is often used in studies that analyze the frequency of occurrence of different categories or outcomes.

# %%
from scipy.stats import chi2_contingency

cont_table = pd.crosstab(crime['STATE/UT'], crime['TOTAL IPC CRIMES'])

# perform chi-square test
chi2, p_val, dof, expected = chi2_contingency(cont_table)

print('Chi-square test results')
print('Chi-square statistic:', chi2)
print('p-value:', p_val)
print('Degrees of freedom:', dof)
print()
if p_val < 0.05:
    print('Reject null hypothesis - There is a significant relationship between STATE/UT and TOTAL IPC CRIMES')
else:
    print('Accept null hypothesis - There is no significant relationship between STATE/UT and TOTAL IPC CRIMES')
# Out:
# Chi-square test results
# Chi-square statistic: 178967.2433389439
# p-value: 1.0
# Degrees of freedom: 190188
#
# Accept null hypothesis - There is no significant relationship between STATE/UT and TOTAL IPC CRIMES

# %% [markdown]
# The p-value is greater than or equal to 0.05, the null hypothesis is accepted and it is concluded that there is no significant relationship between STATE/UT and TOTAL IPC CRIMES.

# %% [markdown]
# # Time series analysis

# %%
import statsmodels.api as sm
plt.figure(figsize=(15,8))

crime_df = pd.read_csv(r"crime.csv", parse_dates=['YEAR'], index_col=['YEAR'])

# Resample data to yearly frequency
crime_yearly = crime_df.resample('Y').sum()

# Plot the time series
plt.plot(crime_yearly.index, crime_yearly['TOTAL IPC CRIMES'])
plt.title('Total IPC Crimes over Time')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.show()

# Decompose the time series into trend, seasonality, and residuals
decomposition = sm.tsa.seasonal_decompose(crime_yearly['TOTAL IPC CRIMES'], model='additive')

# Plot the decomposition results
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(12, 7))
ax1.plot(crime_yearly.index, decomposition.observed)
ax1.set_ylabel('Observed')
ax2.plot(crime_yearly.index, decomposition.trend)
ax2.set_ylabel('Trend')
ax3.plot(crime_yearly.index, decomposition.seasonal)
ax3.set_ylabel('Seasonal')
ax4.plot(crime_yearly.index, decomposition.resid)
ax4.set_ylabel('Residual')
plt.tight_layout()
plt.show()

# Test for stationarity using the Augmented Dickey-Fuller test
adf_result = sm.tsa.stattools.adfuller(crime_yearly['TOTAL IPC CRIMES'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:', adf_result[4])
# Out:
# ADF Statistic: 2.2182534277979373
# p-value: 0.9988971912058884
# Critical Values: {'1%': -4.137829282407408, '5%': -3.1549724074074077, '10%': -2.7144769444444443}

# %%
# Plot ACF
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(crime_yearly['TOTAL IPC CRIMES'])
plt.show()

# %%
# Plot PACF
from statsmodels.graphics.tsaplots import plot_pacf
sm.graphics.tsa.plot_pacf(crime_yearly['TOTAL IPC CRIMES'], lags=5)
plt.title('Partial Autocorrelation Function (PACF)')
plt.xlabel('Lags')
plt.ylabel('Partial Autocorrelation')
plt.show()

# %%
# Estimate the autoregressive integrated moving average (ARIMA) model
model = sm.tsa.ARIMA(crime_yearly['TOTAL IPC CRIMES'], order=(1,1,1))
results = model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:       TOTAL IPC CRIMES   No. Observations:                   13
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -167.382
# Date:                Thu, 12 Dec 2024   AIC                            340.764
# Time:                        18:04:00   BIC                            342.219
# Sample:                    12-31-2001   HQIC                           340.226
#                          - 12-31-2013
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7077      0.243     -2.917      0.004      -1.183      -0.232
# ma.L1          0.7513      0.225      3.336      0.001       0.310       1.193
# sigma2      1.683e+10    2.5e-11   6.73e+20      0.000    1.68e+10    1.68e+10
# ...

# %%
# Plot the actual values and the predicted values
plt.figure(figsize=(15,8))
plt.plot(crime_yearly.index, crime_yearly['TOTAL IPC CRIMES'], label='Actual')
plt.plot(crime_yearly.index, results.predict(start=0, end=len(crime_yearly)-1), label='Predicted')
plt.title('Actual vs Predicted Total IPC Crimes')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.legend()
plt.show()

# %%
# Plot the actual values and the forecasted values
plt.figure(figsize=(15,8))
forecast = results.predict(start=len(crime_yearly), end=len(crime_yearly)+4)
plt.plot(crime_yearly.index, crime_yearly['TOTAL IPC CRIMES'], label='Actual')
plt.plot(forecast.index, forecast, label='Forecast')
plt.title('Actual vs Forecasted Total IPC Crimes')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.legend()
plt.show()

# %% [markdown]
# # Implement machine learning model

# %%
crime.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'CRIME_LEVEL', 'STATE/UT_encoded', 'DISTRICT_encoded'],
#       dtype='object')

# %%
min_val = crime['TOTAL IPC CRIMES'].min()
max_val = crime['TOTAL IPC CRIMES'].max()
range_val = (max_val - min_val) / 4
low = min_val + range_val
medium = low + range_val
high = medium + range_val

# %%
def get_crime_level(crime_count):
    if crime_count <= low:
        return 1
    elif crime_count <= medium:
        return 2
    elif crime_count <= high:
        return 3
    else:
        return 4

crime['CRIME_LEVEL'] = crime['TOTAL IPC CRIMES'].apply(get_crime_level)

# %%
crime_level_count = crime['CRIME_LEVEL'].value_counts()
crime_level_count
# Out:
# CRIME_LEVEL
# 1    9685
# 3      67
# 2      48
# 4      40
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# fit and transform the STATE/UT column using the LabelEncoder
crime["STATE/UT_encoded"] = le.fit_transform(crime["STATE/UT"])

# fit and transform the DISTRICT column using the LabelEncoder
crime["DISTRICT_encoded"] = le.fit_transform(crime["DISTRICT"])

# %%
grouped_state = crime[["STATE/UT", "STATE/UT_encoded"]].groupby("STATE/UT").first()
grouped_state
# Out:
#                    STATE/UT_encoded
# STATE/UT
# A & N ISLANDS                     0
# A&N ISLANDS                       1
# ANDHRA PRADESH                    2
# ARUNACHAL PRADESH                 3
# ASSAM                             4
# BIHAR                             5
# CHANDIGARH                        6
# CHHATTISGARH                      7
# D & N HAVELI                      8
# D&N HAVELI                        9
# DAMAN & DIU                      10
# DELHI UT                         11
# GOA                              12
# GUJARAT                          13
# HARYANA                          14
# HIMACHAL PRADESH                 15
# JAMMU & KASHMIR                  16
# JHARKHAND                        17
# KARNATAKA                        18
# KERALA                           19
# LAKSHADWEEP                      20
# MADHYA PRADESH                   21
# MAHARASHTRA                      22
# MANIPUR                          23
# MEGHALAYA                        24
# ...

# %%
grouped_district = crime[["DISTRICT", "DISTRICT_encoded"]].groupby("DISTRICT").first()
grouped_district
# Out:
#                    DISTRICT_encoded
# DISTRICT
# 24 PARGANAS NORTH                 0
# 24 PARGANAS SOUTH                 1
# A AND N ISLANDS                   2
# ADILABAD                          3
# AGAR                              4
# ...                             ...
# YADGIRI                         823
# YAMUNANAGAR                     824
# YAVATMAL                        825
# ZUNHEBOTO                       826
# ZZ TOTAL                        827
#
# [828 rows x 1 columns]

# %%
crime.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'CRIME_LEVEL', 'STATE/UT_encoded', 'DISTRICT_encoded'],
#       dtype='object')

# %% [markdown]
# # Linear Regression

# %%
X = crime.drop(['CRIME_LEVEL','STATE/UT', 'DISTRICT','TOTAL IPC CRIMES'], axis=1)
y = crime['TOTAL IPC CRIMES']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
lr = LinearRegression()
lr.fit(X_train,y_train)
lr_pred = lr.predict(X_test)
lr_score = lr.score(X_test, y_test)
print('Linear Regression score : ',lr_score)
print()
print('Mean_absolute_error  = ',metrics.mean_absolute_error(lr_pred,y_test))
print()
print('Mean_squared_error   = ',metrics.mean_squared_error(lr_pred,y_test))
print()
print('R2_score             = ',metrics.r2_score(lr_pred,y_test))
print()
R2 = metrics.r2_score(lr_pred,y_test)
adj_R2 = 1-((1-R2)*(len(y)-1)/(len(y)-X.shape[1]-1))
print('Adjusted_R2         = ',adj_R2)
# Out:
# Linear Regression score :  0.9999999999452605
#
# Mean_absolute_error  =  0.006192793044912067
#
# Mean_squared_error   =  0.027504754779580916
#
# R2_score             =  0.9999999999452605
#
# Adjusted_R2         =  0.9999999999450818

# %%
import statsmodels.api as sm
results = sm.OLS(y_train,X_train).fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:       TOTAL IPC CRIMES   R-squared (uncentered):                   0.920
# Model:                            OLS   Adj. R-squared (uncentered):              0.920
# Method:                 Least Squares   F-statistic:                              2738.
# Date:                Thu, 12 Dec 2024   Prob (F-statistic):                        0.00
# Time:                        18:04:08   Log-Likelihood:                         -68527.
# No. Observations:                6888   AIC:                                  1.371e+05
# Df Residuals:                    6859   BIC:                                  1.373e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
import statsmodels.stats.diagnostic as smd

# Assuming 'results' is the result of a regression model, e.g., OLS
# Add a constant term to exogenous variables if it's missing
X_with_constant = sm.add_constant(results.model.exog)

# Perform the Breusch-Pagan test
bp = smd.het_breuschpagan(results.resid, X_with_constant)

# Output the result
name = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
bp_df = pd.DataFrame([bp], columns=name)
print(bp_df)
# Out:
#    Lagrange multiplier statistic  p-value       f-value  f p-value
# 0                       0.000006      1.0  2.153061e-07        1.0

# %% [markdown]
# # Logistic Regression

# %%
X = crime.drop(['CRIME_LEVEL','STATE/UT', 'DISTRICT'], axis=1)
y = crime['CRIME_LEVEL']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
log_pred = log.predict(X_test)
log_score = log.score(X_test, y_test)
log_prob = log.predict_proba(X_test)[:, 1]
print('Logistic regression score : ',log_score)
print()
print(confusion_matrix(y_test, log_pred))
print()
print(classification_report(y_test, log_pred))
# Out:
# Logistic regression score :  0.9925474254742548
#
# [[2892    3    0    0]
#  [   1    7    2    0]
#  [   0    5   18    4]
#  [   0    3    4   13]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2895
#            2       0.39      0.70      0.50        10
#            3       0.75      0.67      0.71        27
#            4       0.76      0.65      0.70        20
#
#     accuracy                           0.99      2952
#    macro avg       0.73      0.75      0.73      2952
# weighted avg       0.99      0.99      0.99      2952

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
svm = SVC(probability=True)
svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)
svm_prob = svm.predict_proba(X_test)[:, 1] if svm.probability else None
svm_score = svm.score(X_test, y_test)
print('Support Vector Machine score : ',svm_score)
print()
print(confusion_matrix(y_test, svm_pred))
print()
print(classification_report(y_test, svm_pred))
# Out:
# Support Vector Machine score :  0.9915311653116531
#
# [[2894    1    0    0]
#  [   2    6    2    0]
#  [   9    1   17    0]
#  [   8    0    2   10]]
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      2895
#            2       0.75      0.60      0.67        10
#            3       0.81      0.63      0.71        27
#            4       1.00      0.50      0.67        20
#
#     accuracy                           0.99      2952
#    macro avg       0.89      0.68      0.76      2952
# weighted avg       0.99      0.99      0.99      2952

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)
dt_prob = dt.predict_proba(X_test)[:, 1]
dt_score = dt.score(X_test, y_test)
print('Decision tree score : ',dt_score)
print()
print(confusion_matrix(y_test, dt_pred))
print()
print(classification_report(y_test, dt_pred))
# Out:
# Decision tree score :  1.0
#
# [[2895    0    0    0]
#  [   0   10    0    0]
#  [   0    0   27    0]
#  [   0    0    0   20]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2895
#            2       1.00      1.00      1.00        10
#            3       1.00      1.00      1.00        27
#            4       1.00      1.00      1.00        20
#
#     accuracy                           1.00      2952
#    macro avg       1.00      1.00      1.00      2952
# weighted avg       1.00      1.00      1.00      2952

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
rf_prob = rf.predict_proba(X_test)[:, 1]
rf_score = rf.score(X_test, y_test)
print('Random forest score : ',rf_score)
print()
print(confusion_matrix(y_test, rf_pred))
print()
print(classification_report(y_test, rf_pred))
# Out:
# Random forest score :  0.9983062330623306
#
# [[2895    0    0    0]
#  [   0   10    0    0]
#  [   0    0   24    3]
#  [   0    0    2   18]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2895
#            2       1.00      1.00      1.00        10
#            3       0.92      0.89      0.91        27
#            4       0.86      0.90      0.88        20
#
#     accuracy                           1.00      2952
#    macro avg       0.95      0.95      0.95      2952
# weighted avg       1.00      1.00      1.00      2952

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
nb_pred = nb.predict(X_test)
nb_prob = nb.predict_proba(X_test)[:, 1]
nd_score = nb.score(X_test, y_test)
print('Naive Bayes score : ',nd_score)
print()
print(confusion_matrix(y_test, nb_pred))
print()
print(classification_report(y_test, nb_pred))
# Out:
# Naive Bayes score :  0.9800135501355014
#
# [[2850   45    0    0]
#  [   0    9    1    0]
#  [   0    3   17    7]
#  [   0    0    3   17]]
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99      2895
#            2       0.16      0.90      0.27        10
#            3       0.81      0.63      0.71        27
#            4       0.71      0.85      0.77        20
#
#     accuracy                           0.98      2952
#    macro avg       0.67      0.84      0.69      2952
# weighted avg       0.99      0.98      0.99      2952

# %% [markdown]
# # Clustering

# %%
X = crime.drop(['STATE/UT', 'DISTRICT','TOTAL IPC CRIMES','CRIME_LEVEL', 'STATE/UT_encoded', 'DISTRICT_encoded'], axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans

X = crime[['MURDER', 'RAPE', 'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT']]
X_scaled = scaler.fit_transform(X)

# Perform k-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X_scaled)

# Visualize clusters and cluster centers
plt.scatter(crime['THEFT'], crime['MURDER'], c=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 4], kmeans.cluster_centers_[:, 0], marker='*', c='red')
plt.xlabel('Number of Thefts')
plt.ylabel('Number of Murders')
plt.show()

# %% [markdown]
# # Hierarchical _Clustering

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
Z = linkage(X_scaled, method='ward')

# Plot dendrogram
plt.figure(figsize=(20, 8))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# Perform hierarchical clustering
hier_clust = AgglomerativeClustering(n_clusters=3)
labels = hier_clust.fit_predict(X_scaled)

# Visualize clusters
plt.scatter(crime['THEFT'], crime['MURDER'], c=labels)
plt.xlabel('Number of Thefts')
plt.ylabel('Number of Murders')
plt.show()

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(X_scaled)

# Visualize clusters
plt.scatter(crime['THEFT'], crime['MURDER'], c=dbscan.labels_)
plt.xlabel('Number of Thefts')
plt.ylabel('Number of Murders')
plt.show()
